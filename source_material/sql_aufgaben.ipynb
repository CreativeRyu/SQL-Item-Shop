# %% [markdown]
# # **SQL Item Shop Academy**
#
# ![image.png](attachment:image.png)
#
# ### **Phase 3 | Missionen & Aufgaben**
#
# Willkommen zurück, Abenteurer.
#
# Bevor du Preise anpasst, Bestellungen bearbeitest oder legendäre Artefakte verwaltest, musst du zuerst verstehen, wie der Shop aufgebaut ist.
#
# Ein guter Händler kennt jedes Regal.
#
# Ein guter Datenbankentwickler kennt jede Tabelle.
#
# Unter jeder Aufgabe findest du eine Code-Zelle für deine SQL-Lösung.

# %% [markdown]
# ***

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # **Level 0 – STRUKTUR**

# %% [markdown]
# ## **Aufgabe 0.1**
#
# Schaue nach welche Tabellen im Laden existieren.\
# Mach dir einen Screenshot und kopiere ihn dir in dein Notizbuch.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 0.2**
#
# Untersuche die Struktur der Datenbank und finde heraus, welche Informationen gespeichert werden.
#
# Nutze dazu den Befehl DESCRIBE. Analysiere die folgenden Tabellen:
#
# + customers
# + products
# + categories
# + suppliers
# + orders
# + order_items
#
# Erstelle anschließend einen Screenshot deiner Ergebnisse und füge ihn in das Notebook ein.
#
# Wer die Struktur einer Datenbank versteht, wird später bessere Abfragen schreiben.

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 1 – SELECT Basics**

# %% [markdown]
# ## **Aufgabe 1**
#
# ![image-3.png](attachment:image-3.png)
#
# Zeige alle Produkte an.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 2**
#
# ![image.png](attachment:image.png)
#
# Zeige nur die Produktnamen an.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 3**
#
# Zeige alle Kunden an.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 4**
#
# Zeige alle aktiven Produkte an.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 5**
#
# Zeige alle Produkte mit Lagerbestand größer als 0.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 6**
#
# Zeige unsere 10 teuersten Produkte an, also die mit dem höchsten Verkaufswert.

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 2 – WHERE**

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## **Aufgabe 7**
#
# Zeige alle Produkte mit Verkaufspreis über 100 Gold.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 8**
#
# Zeige alle Produkte der Kategorie Weapons.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 9**
#
# Zeige alle Kunden aus Berlin.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 10**
#
# Zeige alle Kunden die vor dem Jahr 2000 geboren wurden.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 11**
#
# Suche den Kunden mit der ID 12.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 12**
#
# Zeige alle Kunden mit einem "B" im Nachnamen.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 13**
#
# Zeige alle Produkte deren Name 'Potion' enthält.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 14**
#
# Der Shopkeeper möchte wissen, ob noch genügend Protein Bars auf Lager sind.\
# Suche den Artikel "Protein Bar" und gib den aktuellen Lagerbestand aus.

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 3 – ORDER BY & LIMIT**

# %% [markdown]
# ## **Aufgabe 15**
#
# Sortiere alle Produkte alphabetisch.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 16**
#
# Sortiere alle Produkte nach Verkaufspreis absteigend.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 17**
#
# Zeige die 5 teuersten Produkte aus unserem Laden.

# %%
 -- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 18**
#
# Zeige die 5 günstigsten Produkte aus unserem Laden.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 19**
#
# Zeige die letzten 5 Kunden, die bestellt haben.

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 4 – Aggregatfunktionen**

# %% [markdown]
# ## **Aufgabe 20**
#
# Wie viele Produkte gibt es insgesamt?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 21**
#
# Wie viele Kunden gibt es?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 22**
#
# Wie hoch ist der durchschnittliche Verkaufspreis?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 23**
#
# Welches Produkt ist am teuersten?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 24**
#
# Welches Produkt ist am günstigsten?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 25**
#
# Wie viele Produkte sind aktiviert?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 26**
#
# Wie viele Produkte sind deaktiviert?

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 5 – GROUP BY**

# %% [markdown]
# ## **Aufgabe 27**
#
# Wie viele Produkte gibt es pro Kategorie?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 28**
#
# Wie viele Kunden wohnen in jeder Stadt?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 29**
#
# Wie viele Produkte liefert jeder Lieferant?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 30**
#
# Wie viele Bestellungen hat jeder Kunde?
# Es kann auch Kunden ohne Bestellug geben.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 31**
#
# Wie hoch ist der Gesamtumsatz pro Kunde?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 32**
#
# Gib die Anzahl und den Namen verkaufter Artikel aus dem Jahr 2024 aus,\
# sortiert nach den meistverkauften Artikeln.

# %% [markdown]
# ***

# %% [markdown]
# # **Level 6 – HAVING**

# %% [markdown]
# ## **Aufgabe 33**
#
# Zeige Städte mit mehr als 4 Kunden.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 34**
#
# Zeige Kategorien mit mehr als 5 Produkten.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 35**
#
# Zeige Kunden mit mehr als 3 Bestellungen.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 36**
#
# Zeige Lieferanten mit mehr als 10 Produkten.

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 7 – JOIN**

# %% [markdown]
# ## **Aufgabe 37**
#
# Zeige alle Produkte inklusive Kategorienamen.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 38**
#
# Zeige alle Produkte inklusive Lieferant.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 39**
#
# Zeige alle Bestellungen mit Kundennamen.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 40**
#
# Zeige alle Bestellpositionen inklusive Produktname.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 41**
#
# Zeige alle Bestellungen inklusive Kundennamen und Bestellsumme.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 42**
#
# Gib alle offenen Beträge inklusive Kunde aus.

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 8 – Mehrfach JOINs**

# %% [markdown]
# ## **Aufgabe 43**
#
# Welche Produkte wurden bestellt?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 44**
#
# Welche Kunden haben welche Produkte gekauft?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 45**
#
# Wie oft wurde jedes Produkt verkauft?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 46**
#
# Wie hoch ist der Umsatz jedes Produkts?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 47**
#
# Welche Kategorie wurde am häufigsten verkauft?

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 48**
#
# Gib die 5 beliebtesten Artikel aus.

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 9 – Subqueries**

# %% [markdown]
# ## **Aufgabe 49**
#
# Zeige alle Produkte die teurer sind als der Durchschnitt.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 50**
#
# Zeige alle Kunden ohne Bestellung.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 51**
#
# **Der Shopkeeper**
#
# "Manche Gegenstände stehen seit Jahren im Regal und sammeln mehr Staub als Gold."
#
# "Finde heraus, welche Produkte noch nie verkauft wurden."

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 52**
#
#
# "Einige Kunden haben unseren Laden schon lange nicht mehr besucht."
#
# "Finde alle Kunden, die im Jahr 2024 keine Bestellung aufgegeben haben."

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 53**
#
# Zeige den Kunden mit den meisten Bestellungen.

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 54**
#
# Zeige das meistverkaufte Produkt.

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 10 – INSERT / UPDATE / DELETE**

# %% [markdown]
# ## **Aufgabe 55**
#
# **Der Shopkeeper**
#
# "Ein junger Krieger hat gerade seinen ersten Trainingsvertrag unterschrieben."
#
# "Er behauptet, nächstes Jahr beim Deadlift-Turnier anzutreten."
#
# "Füge ihn als neuen Kunden in die Datenbank ein."

# %% [markdown]
# ```text
# Vorname: Grom
# Nachname: Eisenfaust
# Geburtsdatum: 1997-06-15
# Stadt: Ironforge
# Registrierungsdatum: 2025-01-15
# Aktiv: TRUE
# E-Mail: grom.eisenfaust@mail.de
# Rabatt: 0

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 56**
#
# **Der Shopkeeper**
#
# "Vor einem Jahr wollten alle noch Schwerter und Protein Shakes."
#
# "Jetzt reden plötzlich alle nur noch über Calisthenics."
#
# "Jeder zweite Kunde fragt nach Dip Bars."
#
# "Nimm das neue Produkt in unser Sortiment auf."
#
# **Produktdaten:**

# %% [markdown]
# ```text
# Name: Dip Bars
# Kategorie: Equipment
# Lieferant: Ironforge Supplies
# Einkaufspreis: 39.99 Gold
# Verkaufspreis: 79.99 Gold
# Aktiv: TRUE
# Lagerbestand: 15

# %%
-- SQL hier eingeben

# %% [markdown]
# "Früher wollten die Leute Drachen töten."\
# "Heute machen sie Muscle-Ups im Park."\
# "Die Zeiten ändern sich."

# %% [markdown]
# ## **Aufgabe 57**
#
# **Der Shopkeeper**
#
# "Die Zeiten werden härter."
#
# "Die Karawanen verlangen höhere Preise, die Rohstoffe werden teurer und selbst Creatine kostet mittlerweile mehr Gold als früher."
#
# "Um die steigenden Kosten auszugleichen, müssen alle Supplements um 10 % teurer werden."
#
# "Passe die Verkaufspreise entsprechend an."

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 58**
#
# **Der Shopkeeper**
#
# "Die Verträge mit Dragon Merchants sind ausgelaufen."
#
# "Nach langen Verhandlungen übernimmt Ironforge Supplies die Belieferung aller betroffenen Produkte."
#
# "Aktualisiere die Lieferantenzuordnung."

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 59**
#
# **Der Shopkeeper**
#
# "Ein Kunde hat behauptet, unser Mass Gainer schmecke wie nasse Pappe."
#
# "Drei weitere Kunden haben zugestimmt."
#
# "Bis wir die Rezeptur verbessern, nehmen wir das Produkt aus dem Sortiment."

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 60**
#
# **Der Shopkeeper**
#
# "Wer regelmäßig trainiert, bekommt Respekt."
#
# "Wer regelmäßig Gold im Shop ausgibt, bekommt Rabatt."
#
# "Unsere treuesten Kunden sollen belohnt werden."
#
# "Alle Kunden, die mindestens eine Bestellung über 100 Gold aufgegeben haben, erhalten einen Rabatt von 10 %."

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 61**
#
# "Ein Kunde hat drei Regale umgeworfen, zwei Protein-Shakes gestohlen und behauptet, Creatine sei Magie."
#
# "Der Stadtrat hat ein dauerhaftes Hausverbot ausgesprochen."
#
# "Entferne den Kunden mit der ID 15."

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 62 Bonus**
#
#
# "Einige Kunden haben ihren Account erstellt, aber nie etwas gekauft."
#
# "Um die Datenbank aufzuräumen, sollen inaktive Kundenkonten entfernt werden."
#
# "Lösche alle Kunden, die seit mehr als 3 Jahren registriert sind und noch nie eine Bestellung aufgegeben haben."

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 11 – DDL & Datenbankdesign**

# %% [markdown]
# ## **Aufgabe 63**
#
# ![image-2.png](attachment:image-2.png)
#
# **Der Shopkeeper**
#
# "Früher kamen die Leute nur für Protein Shakes und Ausrüstung."
#
# "Heute trainieren viele direkt im kleinen Gym hinter dem Laden."
#
# "Die Mitgliederzahlen steigen ständig und ich verliere langsam den Überblick."
#
# "Erstelle eine Tabelle gym_memberships, um die Mitgliedschaften im Shopkeeper Gym zu verwalten."
#
# Die Tabelle soll:
#
# + eine eindeutige Mitgliedschafts-ID besitzen
# + auf einen Kunden verweisen
# + das Eintrittsdatum speichern
# + den Mitgliedsstatus (aktiv/inaktiv) speichern

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 64**
#
# **Der Shopkeeper**
#
# "Nicht jedes Produkt ist gleich selten."
#
# "Ein Protein Shake findet sich überall."
#
# "Ein Dragon Orb dagegen nur einmal im Königreich."
#
# "Erweitere die Produkttabelle um eine Spalte namens rarity."

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 65**
#
# **Der Shopkeeper**
#
# "Früher lagerten alle Waren im Hinterzimmer."
#
# "Mittlerweile besitzen wir mehrere Lagerhäuser im ganzen Königreich."
#
# "Damit wir unsere Bestände besser verwalten können, benötigen wir eine eigene Lagertabelle."
#
# Erstelle eine Tabelle warehouses.
#
# Die Tabelle soll:
#
# + eine eindeutige Lager-ID besitzen
# + einen Lagernamen speichern
# + den Standort des Lagers speichern

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 66**
#
# **Der Shopkeeper**
#
# "Ein Produkt kann inzwischen in mehreren Lagern gleichzeitig liegen."
#
# "Unser altes System stößt an seine Grenzen."
#
# "Erstelle eine Tabelle warehouse_stock, welche Produkte und Lager miteinander verknüpft."
#
# Die Tabelle soll:
#
# + auf ein Lager verweisen
# + auf ein Produkt verweisen
# + den aktuellen Lagerbestand speichern

# %%
-- SQL hier eingeben

# %% [markdown]
# ## **Aufgabe 67**
#
# **Der Shopkeeper**
#
# "Die neuen Lagerhäuser stehen bereit."
#
# "Jetzt müssen wir die bestehenden Bestände übernehmen."
#
# "Übertrage alle Lagerbestände aus products.stock in das Hauptlager."

# %%
INSERT INTO warehouse_stock
(
    warehouse_id,
    product_id,
    stock
)
SELECT
    1,
    product_id,
    stock
FROM products;

# %% [markdown]
# ## **Aufgabe 68**
#
# **Der Shopkeeper**
#
# "Alle Bestände wurden erfolgreich in die neue Lagerverwaltung übertragen."
#
# "Die Spalte stock wird nicht mehr benötigt."
#
# "Entferne sie aus der Tabelle products."

# %%
-- SQL hier eingeben

# %% [markdown]
# ***

# %% [markdown]
# # **Level 12 – TCL**

# %% [markdown]
# ## **Aufgabe 69**
#
# **Der Shopkeeper**
#
# "Die Karawanen sind eingetroffen."
#
# "Die letzten Wochen waren chaotisch."
#
# "Neue Waren wurden geliefert, Preise mussten angepasst werden und einige seltene Artefakte wurden wiedergefunden."
#
# "Alle Änderungen müssen gemeinsam gespeichert werden."
#
# "Führe deshalb alle Anpassungen innerhalb einer Transaktion durch."
#
# **Inventurbericht**
#
# + Creatine: +50 Stück
# + Protein Shake: +100 Stück
# + Lifting Belt: +10 Stück
# + Banana: +50 Stück
# + Katana: +3 Stück
#
# **Preisanpassungen**
#
# + Erhöhe alle Waffenpreise um 5 %
# + Erhöhe den Preis des Dragon Orb um 10 %
# + Erhöhe den Preis vom Dragon Scale Armor um 5 %
#
# **Sortiment**
#
# + Ancient Crown soll wieder verkauft werden (active = TRUE)
# + Crystal Skull bleibt archiviert
#
# **Abschluss**
#
# "Die neuen Lagerhäuser sind nun in Betrieb."
#
# "Alle Bestände werden ab sofort über die Lagerverwaltung geführt."
#
# "Starte eine Transaktion."
#
# "Führe alle Änderungen durch."
#
# "Speichere die Änderungen erst, wenn die Inventur erfolgreich abgeschlossen wurde."

# %%
-- Vorher


-- Nachher

# %% [markdown]
# ## **Aufgabe 70**
#
# **Der Shopkeeper**
#
# "Unser Archiv ist vorbereitet."
#
# "Bestellungen aus dem Jahr 2022 werden nur noch selten benötigt."
#
# "Bevor wir sie aus der aktiven Tabelle entfernen, müssen sie sicher im Archiv gespeichert werden."
#
# Übertrage alle Bestellungen aus dem Jahr 2022 in die Tabelle archived_orders.
#
# Entferne die archivierten Datensätze anschließend aus der aktiven Tabelle orders.
